# %%
print("Name: Ishan")
print("We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level")
print("We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it")
# Out:
# Name: Ishan
# We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level
# We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it

# %% [markdown]
# # Task 1 - Find the diabetic and hight blood pressure patients across all age groups, and conclude the risk heart stroke is higher in which age group

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt 

#read the csv
df = pd.read_csv('heart_disease.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# ...

# %%
diabetes = df.loc[df['diabetes'] == 1]
diabetes
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.0        1                       160         1                 20
# 7    60.0        1                       315         1                 60
# 19   48.0        1                       582         1                 55
# 21   65.0        1                       128         1                 30
# 23   53.0        0                        63         1                 60
# ..    ...      ...                       ...       ...                ...
# 290  45.0        0                       615         1                 55
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 296  45.0        0                      2060         1                 60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# ...

# %%
dia_age_grp = diabetes.groupby('age')['diabetes'].count().reset_index()
dia_age_grp
# Out:
#        age  diabetes
# 0   40.000         2
# 1   42.000         2
# 2   44.000         2
# 3   45.000        11
# 4   46.000         1
# 5   48.000         2
# 6   49.000         1
# 7   50.000        12
# 8   51.000         2
# 9   52.000         2
# 10  53.000         3
# 11  54.000         1
# 12  55.000         4
# 13  56.000         1
# 14  58.000         5
# 15  59.000         3
# 16  60.000        19
# 17  60.667         2
# 18  61.000         2
# 19  62.000         3
# 20  63.000         4
# 21  65.000        15
# 22  66.000         1
# 23  68.000         2
# 24  69.000         1
# 25  70.000         9
# 26  72.000         2
# 27  73.000         1
# 28  75.000         3
# 29  80.000         3
# 30  82.000         2
# 31  90.000         1
# 32  94.000         1

# %%
high_bp = df.loc[df['high_blood_pressure'] == 1]
high_bp
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# ..    ...      ...                       ...       ...                ...
# 255  52.0        1                       191         1                 30
# 257  58.0        0                       132         1                 38
# 270  44.0        0                       582         1                 30
# 275  45.0        0                       582         0                 38
# 294  62.0        0                        61         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# ...

# %%
bp_age_grp = high_bp.groupby('age')['high_blood_pressure'].count().reset_index()
bp_age_grp
# Out:
#        age  high_blood_pressure
# 0   40.000                    1
# 1   44.000                    2
# 2   45.000                    5
# 3   46.000                    2
# 4   48.000                    1
# 5   49.000                    3
# 6   50.000                   10
# 7   51.000                    1
# 8   52.000                    1
# 9   53.000                    3
# 10  54.000                    1
# 11  55.000                    4
# 12  57.000                    1
# 13  58.000                    3
# 14  59.000                    2
# 15  60.000                    9
# 16  60.667                    1
# 17  61.000                    2
# 18  62.000                    3
# 19  63.000                    2
# 20  65.000                    8
# 21  66.000                    2
# 22  68.000                    2
# 23  70.000                   13
# 24  72.000                    5
# 25  73.000                    2
# 26  75.000                    7
# 27  77.000                    1
# ...

# %%
fig = plt.figure(figsize=(19,8))

label = dia_age_grp['age']
value = dia_age_grp['diabetes']

plt.scatter(label,value,label="Diabetes cases in different age groups", color="blue", alpha=1, s=value*5)

fig1 = plt.figure(figsize=(19,8))

label1 = bp_age_grp['age']
value1 = bp_age_grp['high_blood_pressure']

plt.scatter(label1, value1,label="High BP cases in different age groups", color="red", alpha=1, s=value1*5)

# %% [markdown]
# Conclusion -

# %% [markdown]
# # Task 2 - Find as per gender who has not normal platelets level in blood

# %%
#Filter by platelets(condition lesser then 150000 OR greater then 450000) and create new dataframe

platelets = df.loc[(df['platelets'] < 150000) | (df['platelets'] > 450000)]
platelets
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 6    75.0        1                       246         0                 15
# 7    60.0        1                       315         1                 60
# 12   45.0        1                       981         0                 30
# 15   82.0        1                       379         0                 50
# 19   48.0        1                       582         1                 55
# 25   80.0        0                       148         1                 38
# 47   60.0        0                       582         1                 38
# 48   80.0        1                       553         0                 20
# 55   95.0        1                       371         0                 30
# 65   60.0        0                        68         0                 20
# 69   65.0        0                       113         1                 25
# 71   58.0        0                       582         1                 35
# ...

# %%
gender_grp = platelets.groupby('gender')['platelets'].count().reset_index()
gender_grp
# Out:
#    gender  platelets
# 0       0         11
# 1       1         29

# %%
label = gender_grp['gender']
value = gender_grp['platelets']

plt.pie(value,labels=label,autopct="%0.2f%%", radius=2)
plt.show()

# %% [markdown]
# Conclusion -
